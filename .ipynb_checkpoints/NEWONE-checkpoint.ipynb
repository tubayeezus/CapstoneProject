# %%
import import_ipynb
import tensorflow as tf
import matplotlib.pyplot as plt
import PIL
from PIL import Image
import glob
import cv2
import os
import numpy as np
import pandas as pd
import shap
import json
from pandas.plotting import scatter_matrix
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import random
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import RMSprop
# Out:
# 2023-09-27 23:40:05.382307: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)

# %%
# img = image.load_img("/Users/rodrigorenteria/Desktop/Computer_vision/base_data/training/gun/2.jpeg")

# %%
# plt.imshow(img)

# %%
cv2.imread("CapstoneProject/Computer_vision/base_data/training/gun/2.jpeg").shape
# Out:
# [ WARN:0@13.104] global loadsave.cpp:248 findDecoder imread_('CapstoneProject/Computer_vision/base_data/training/gun/2.jpeg'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 cv2.imread("CapstoneProject/Computer_vision/base_data/training/gun/2.jpeg").shape
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
train = ImageDataGenerator(rescale = 1/255)
validation = ImageDataGenerator(rescale = 1/255)

# %%
train_dataset = train.flow_from_directory("CapstoneFolder/Computer_vision/base_data/training/",
                                          target_size = (200,200),
                                          batch_size = 3,
                                          classes=['gun', 'nogun'],
                                          class_mode = 'binary')
validation_dataset = train.flow_from_directory("CapstoneFolder/Computer_vision/base_data/validation/",
                                          target_size = (200,200),
                                          batch_size = 3,
                                            classes=['gun', 'nogun'],
                                          class_mode = 'binary')
# Out:
# Found 198 images belonging to 2 classes.
# Found 38 images belonging to 2 classes.

# %%
model = tf.keras.models.Sequential([tf.keras.layers.Conv2D(16,(3,3),activation = 'relu', input_shape = (200,200,3)),
                                    tf.keras.layers.MaxPool2D(2,2),
                                    tf.keras.layers.Conv2D(32,(3,3),activation = 'relu'),
                                    tf.keras.layers.MaxPool2D(2,2),
                                    tf.keras.layers.Conv2D(64,(3,3),activation = 'relu'),
                                    tf.keras.layers.RandomFlip("horizontal",input_shape=(200,200,3)),
                                    tf.keras.layers.RandomRotation(0.1),
                                    tf.keras.layers.RandomZoom(0.1),
                                    tf.keras.layers.MaxPool2D(2,2),
                                    tf.keras.layers.Flatten(),
                                    tf.keras.layers.Dropout(0,2),
                                    tf.keras.layers.Dense(128,activation='relu'),
                                    tf.keras.layers.Dense(1,activation='sigmoid')
                                    ])

# %%
model.compile(loss='binary_crossentropy',
              optimizer = RMSprop(learning_rate=0.001),
              metrics = ['accuracy'])

model.summary()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_48 (Conv2D)          (None, 198, 198, 16)      448
#
#  max_pooling2d_48 (MaxPooli  (None, 99, 99, 16)        0
#  ng2D)
#
#  conv2d_49 (Conv2D)          (None, 97, 97, 32)        4640
#
#  max_pooling2d_49 (MaxPooli  (None, 48, 48, 32)        0
#  ng2D)
#
#  conv2d_50 (Conv2D)          (None, 46, 46, 64)        18496
#
#  random_flip_4 (RandomFlip)  (None, 46, 46, 64)        0
#
#  random_rotation_4 (RandomR  (None, 46, 46, 64)        0
#  otation)
#
#  random_zoom_4 (RandomZoom)  (None, 46, 46, 64)        0
#
#  max_pooling2d_50 (MaxPooli  (None, 23, 23, 64)        0
#  ng2D)
#
#  flatten_16 (Flatten)        (None, 33856)             0
#
#  dropout_4 (Dropout)         (None, 33856)             0
#
#  dense_32 (Dense)            (None, 128)               4333696
#
#  dense_33 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 4357409 (16.62 MB)
# Trainable params: 4357409 (16.62 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(train
# Epoch 39/40
# 66/66 [==============================] - 7s 101ms/step - loss: 0.1530 - accuracy: 0.9444 - val_loss: 0.7909 - val_accuracy: 0.7632
# Epoch 40/40
# 66/66 [==============================] - 6s 95ms/step - loss: 0.1870 - accuracy: 0.9293 - val_loss: 0.5877 - val_accuracy: 0.7368

# %%
model.save_weights('model_weights_after_40_epochs.h5')


acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(40)

plt.figure(figsize=(16, 6))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# Generate predictions for the validation dataset
validation_predictions = model.predict(validation_dataset)

# Get the true labels for the validation dataset
true_labels = validation_dataset.classes

# Generate a confusion matrix
cm = confusion_matrix(true_labels, validation_predictions > 0.5)

# Display the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=['gun', 'nogun'], yticklabels=['gun', 'nogun'])
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

accuracy_percentage = overall_accuracy * 100
error_percentage = 100 - accuracy_percentage

# Create a pie chart
labels = ['Accuracy', 'Error']
sizes = [accuracy_percentage, error_percentage]
colors = ['#66b3ff', '#ff9999']  # Blue for accuracy, Red for error

plt.figure(figsize=(6, 6))
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.title('Model Overall Accuracy')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

overall_accuracy = model.evaluate(validation_dataset)[1]
print(f'Overall Accuracy: {overall_accuracy * 100:.2f}%')
# Out:
# 13/13 [==============================] - 0s 20ms/step
# 13/13 [==============================] - 0s 15ms/step - loss: 1.5913 - accuracy: 0.8158
# Overall Accuracy: 81.58%

# %%
# Show some image examples with predictions
def show_random_images_with_predictions(dataset, predictions, num_examples=10):
    plt.figure(figsize=(16, 10))
    
    for i in range(num_examples):
        index = random.randint(0, len(dataset) - 1)
        image_batch, label_batch = dataset[index]
        
        # Take the first image from the batch (index 0)
        image = image_batch[0]
        label = label_batch[0]
        
        prediction = "gun" if predictions[index][0] > 0.5 else "nogun"
        
        plt.subplot(1, num_examples, i + 1)
        plt.imshow(image)
        plt.title(f"True: {label}\nPred: {prediction}")
        plt.axis('off')
    
    plt.show()

show_random_images_with_predictions(validation_dataset, validation_predictions)

# %%
print("Hello! Please upload a JPEG image to the 'CapstoneFolder/Computer_vision/base_data/testing' folder.")
print("Once uploaded, please enter the filename,ex : ('image1.jpg') program will access the image and predict whether it contains a gun or not.")

dir_path = 'CapstoneFolder/Computer_vision/base_data/testing'
# model.evaluate(validation_dataset)
yes = True
while(yes):
    file = input("Enter here: ")
    for i in os.listdir(dir_path):
        if not i.startswith('.') and i == file :
            img = image.load_img(dir_path+'/'+i, target_size=(200,200,3))
            plt.imshow(img)
            plt.show()

            X = image.img_to_array(img)
            X = np.expand_dims(X,axis = 0)
            images = np.vstack([X])
            val = model.predict(images)
            if val == 0:
                print("There is a gun(s)")
                yes = False
                break
            else:
                print("There is no gun")
                yes = False
                break
# Out:
# Hello! Please upload a JPEG image to the 'Computer_vision/base_data/testing' folder.
# Once uploaded, please enter the filename,ex : ('image1.jpg') program will access the image and predict whether it contains a gun or not.
# Enter here:  image179.jpg
# 1/1 [==============================] - 0s 358ms/step
# There is no gun
